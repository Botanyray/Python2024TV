# %% [markdown]
# https://github.com/Botanyray/Python-TV

# %% [markdown]
# https://github.com/Botanyray/Python-TV

# %% [markdown]
# <h1>Esercizio 1 <h1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h1>Esercizio 2 <h1>

# %% [markdown]
# Nel file scarica.txt disponibile al link: https://github.com/Botanyray/Python-TV/blob/main/scarica.txt trovate dei dati sperimentali che rappresentano la caduta di tensione ai capi di un condensatore durante il processo di scarica. Si riportano i valori di tensione e relative incertezze in funzione del tempo.
#
# 1. Importate i dati
# 2. Plottate V(t) e relativi errori in funzione di t.
# 3. $ln[V(t)]$ e relativo errore in funzione di t.
# 4. fittate i  dati in 2. alla funzione V(t)=$V_{o}$*$exp[-t/\tau$] Trovando i valori di best fit per $V_{0}$ e $\tau$.
# 5. Fittate 3. attraverso una retta.
# 6. Rappresentate le curve fittate come curve continue mentre i dati stessi come scatter points con errori.
